# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhsingh092/Davis_lab_work/blob/main/loginsystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username = "admin"
password = "1234"

attempts = 0

while attempts < 3:
    u = input("Enter username: ")
    p = input("Enter password: ")

    if u == username and p == password:
        print("Login Successful")
        break
    else:
        print("Wrong details")
        attempts += 1

if attempts == 3:
    print("Account Locked")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful
