# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhsingh092/Davis_lab_work/blob/main/atmwithdrawal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def atm_withdrawal():
    balance = 10000  # starting balance

    while True:
        print("\n1. Withdraw")
        print("2. Exit")
        choice = input("Enter choice: ")

        if choice == "1":
            amount = float(input("Enter amount to withdraw: "))

            if amount < 0:
                print("Invalid amount!")
            elif amount > balance:
                print("Insufficient balance!")
            else:
                balance -= amount
                print("Withdrawal successful. Remaining balance:", balance)

        elif choice == "2":
            print("Exiting ATM. Goodbye!")
            break
        else:
            print("Invalid choice!")

# Run the ATM system
atm_withdrawal()
# Out:
# 1. Withdraw
# 2. Exit
# Enter choice: 1
# Enter amount to withdraw: 1000
# Withdrawal successful. Remaining balance: 9000.0
#
# 1. Withdraw
# 2. Exit
