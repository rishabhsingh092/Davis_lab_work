# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhsingh092/Davis_lab_work/blob/main/numberclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def classify(num):
    if num > 0:
        print("Positive")
    elif num < 0:
        print("Negative")
    else:
        print("Zero")

    # Even or Odd
    if num != 0:
        if num % 2 == 0:
            print("Even")
        else:
            print("Odd")

numbers = [1, -2, 0, 5]

for n in numbers:
    print("\nNumber:", n)
    classify(n)
# Out:
# Number: 1
# Positive
# Odd
#
# Number: -2
# Negative
# Even
#
# Number: 0
# Zero
#
# Number: 5
# Positive
# Odd
