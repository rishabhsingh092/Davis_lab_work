# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhsingh092/Davis_lab_work/blob/main/multiplicationtable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to print multiplication table
def multiplication_table(number):
    if number < 0:
        print("Negative numbers are not allowed!")
        return  # exit the function if input is negative

    # Loop from 1 to 10
    for i in range(1, 11):
        print(f"{number} x {i} = {number * i}")

# Take input from user
num = int(input("Enter a number: "))
multiplication_table(num)
# Out:
# Enter a number: 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
